# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
x = torch.empty(10).normal_(mean=0,std=0.05).numpy()
y = torch.empty(10).normal_(mean=0,std=0.05).numpy()
z = torch.empty(10).normal_(mean=0,std=0.05).numpy()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x, y ,z)
